# %%
import sys
import os
import datetime
from math import radians, cos, sin, asin, sqrt

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %pip install sweetviz
import sweetviz as sv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
all_flights = pd.read_csv('LONESTAR_2022_ALL.csv', sep=';')
all_flights.shape
# Out:
# (216, 30)

# %%
clean

# %%
all_flights
# Out:
#      Flightnumber        Date Starttime(UTC)          Pilot  Country    Site  \
# 0              76  09.08.2022          17:14            NaN      NaN     NaN
# 1              37  08.08.2022          16:23            UNK      NaN     NaN
# 2             147  11.08.2022          17:51            NaN      NaN     NaN
# 3             201  13.08.2022          17:31  Moacir Thiele      NaN     NaN
# 4              67  09.08.2022          16:35          Emily      NaN     NaN
# ..            ...         ...            ...            ...      ...     ...
# 211            38  08.08.2022          16:24   Lindsey Ripa      NaN     NaN
# 212            41  08.08.2022          16:39   Rick Fullmer      NaN     NaN
# 213             3  07.08.2022          17:04      Felix Fig      NaN  Hearne
# 214           165  12.08.2022          16:26      Felix Fig      NaN       ?
# 215            25  07.08.2022          19:26   Rick Fullmer      NaN     NaN
#
# ...
