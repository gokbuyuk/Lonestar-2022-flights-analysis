# %%
# %%
tasks_summary = ls_tracks.groupby('Task')['Flight Duration'].sum().rename('Total Flight Time').reset_index()
tasks_summary

# %%
dist = tasks.groupby(['Task', 'GliderClass'])['Distance'].median().rename('Total Distance Flown').reset_index()
sns.lineplot(data=dist, x='Task', y='Total Distance Flown', hue='GliderClass')

# %%
sns.boxplot(data=tasks, x='Task', y='Distance', hue='GliderClass', 
            # alpha=0.5, 
            # jitter=True,
            # kind = 'box'
            )
sns.stripplot(data=tasks, x='Task', y='Distance', hue='GliderClass', 
            alpha=0.5, 
            jitter=True,
            split=True,
            # kind = 'box'
            )

# %%
sns.boxplot(data=ls, x='Task', y='Max Vario', hue='GliderClass', 
            # alpha=0.5, 
            # jitter=True,
            # kind = 'box'
            )
sns.stripplot(data=ls, x='Task', y='Max Vario', hue='GliderClass', 
            alpha=0.5, 
            jitter=True,
            # kind = 'box'
            )

# %%
ls['Launch Time']

# %% [markdown]
# ## Launch Time

# %%
for i in range(1,8):
    sns.scatterplot(data=ls[(ls['Max Vario']<20) & (ls['Task']==i)], x='Launch Time', y='Max Vario', hue='Made Goal')
    plt.xticks(rotation=90)
    plt.title('Task {}-Max Vario by Launch Time'.format(i))
    plt.ylim(0,10)
    plt.show()

# %%

ls.head()

# %%
ls.columns

# %%
ls.loc[ls['Pilot']=='Austin Kasserman', ['Pilot', 'Task', 'Max Vario']]

# %%

ls_tracks.columns

# %%

tasks[['Pilot', 'GliderClass']]

# %%

ls.columns

# %%
ls.loc[ls['Pilot']=='Gokcen Buyukbas', ['Task', 'Distance', 'Min Vario', 'Max Vario']]

# %%
lsraw_report = sv.analyze(ls)


# %%
lsraw_report.show_html('Lonestar2022.html')

# %%
